# %% [markdown]
# ### THE SPARKS FOUNDATION

# %% [markdown]
# ### TASK 3: EXPLORATORY DATA ANALYSIS ON RETAIL

# %% [markdown]
# **TASK:Find out the weak areas where you can work to make more profit.**

# %% [markdown]
# Author: Derlin dominic

# %% [markdown]
# ### Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set(style="whitegrid", color_codes=True)

# %% [markdown]
# ### Loading Dataset

# %%
import pandas as pd
retail=pd.read_csv("C:\\Users\\DERLIN DOMINIC\\Desktop\\SampleSuperstore.csv",encoding='unicode_escape')
retail
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# This dataset is about a retail store. With data analysis we will get insights on how the company can increase its profits while minimizing its losses.We have 9994 rows and 13 columns in this data.we have 414 rows and 8 columns in this data.

# %%
retail.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
retail.shape
# Out:
# (9994, 13)

# %% [markdown]
# ###  Statistical Description

# %%
retail.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
retail.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ### TESTING FOR MISSING VALUES

# %%
print(retail.isnull().sum())
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
retail.Country.unique()
# Out:
# array(['United States'], dtype=object)

# %% [markdown]
# ### Dropping irrelevant columns

# %%
retail = retail.drop(['Postal Code', 'Country'], axis=1)
retail.head()
# Out:
#         Ship Mode    Segment             City       State Region  \
# 0    Second Class   Consumer        Henderson    Kentucky  South
# 1    Second Class   Consumer        Henderson    Kentucky  South
# 2    Second Class  Corporate      Los Angeles  California   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida  South
#
#           Category Sub-Category     Sales  Quantity  Discount    Profit
# 0        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %% [markdown]
# ### DATA VISUALIZATION

# %%
plt.figure(figsize=(10,5))
c= retail.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %%
sns.regplot(x="Profit",y="Discount",data=retail)
plt.ylim(0,)
# Out:
# (0.0, 2.1530385510684185)

# %% [markdown]
# **We can see a negative correlation between Discount and Profit**

# %%
sns.regplot(x="Profit",y="Sales",data=retail)
plt.ylim(0,)
# Out:
# (0.0, 24342.3672479331)

# %% [markdown]
# **There is a Positive correlation between Sales and Profit**

# %%
plt.figure(figsize=(12,6))
plt.bar('Sub-Category','Category', data=retail)
plt.title('Category vs Sub Category')
plt.xlabel('Sub-Catgory')
plt.ylabel('Category')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(15,12))
retail['Sub-Category'].value_counts().plot.pie(autopct='%1.1f%%').set_title('SUB CATEGORIES')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=retail['Sub-Category'])
plt.xticks(rotation=90)
plt.show()

# %%
ps = retail.groupby('Sub-Category')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False)
ps[:].plot.bar(figsize=(15,10))
plt.title('Profit/Loss and Sales across states')
plt.xlabel('Sub-Category')
plt.ylabel('Profit/Loss and Sales')
plt.show()

# %% [markdown]
# - Highest Sales is for Binders,Papers and Furnishings
# - Lowest is for Supplies,Machines and Copiers
# - Phones,Chairs,Storage has highest Sales in sub category
# - Tables,Bookcases,Supllies are the sub categories that has least Profit

# %%
plt.figure(figsize=(10,15))
sns.countplot(x=retail['State'])
plt.xticks(rotation=90)
plt.title("STATE")
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(15,5))
ax[0].set_title('Discount vs Profit', fontsize=15)
ax[1].set_title('Quantity vs Profit', fontsize=15)
sns.lineplot(retail.Discount, retail.Profit, color='green', label='Profit Change', ax=ax[0])
sns.lineplot(retail.Quantity, retail.Profit, color='red', label='Profit Change', ax=ax[1])
plt.show()
# Out:
# C:\Users\DERLIN DOMINIC\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DERLIN DOMINIC\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(x=retail['Segment'])
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='count'>

# %% [markdown]
# As we can see in this graph highest Segment is Consumer Segment following with Corporate & Home Office

# %%
sns.countplot(x='Category',data=retail).set_title('CATEGORY')
# Out:
# Text(0.5, 1.0, 'CATEGORY')

# %%
retail.groupby('Category')['Sales','Profit'].sum().plot.bar()
plt.title('Sale & profit in different categories')
plt.legend(loc=1)
plt.show()
# Out:
# <ipython-input-16-cff3f0b69696>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   retail.groupby('Category')['Sales','Profit'].sum().plot.bar()

# %% [markdown]
# - Technology & Furniture has more sales than Office Supllies
# - In case of Profit Furniture has least value

# %%
sns.countplot(x=retail['Region'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %% [markdown]
# Highest Sales Occurs at West & East Regions

# %%
segment2=retail[['Category','Region','Profit']]
reg_analysis=segment2.groupby(['Category','Region'],as_index=False).mean()

# %%
pivot=reg_analysis.pivot(index='Region',columns='Category')
pivot
# Out:
#              Profit
# Category  Furniture Office Supplies Technology
# Region
# Central   -5.968918        6.244712  80.231981
# East       5.068496       23.957114  88.714084
# South     20.395199       20.086827  68.231506
# West      16.272914       27.733183  73.962687

# %%
ax = sns.heatmap(pivot, annot=True,linewidth=.05)

# %% [markdown]
# - Technology Category has the highest profit at East Region
# - Furniture has the least profit at Central Region

# %%
fig, ax = plt.subplots(figsize = (10 , 6))
ax.scatter(retail["Sales"] , retail["Profit"])
ax.set_xlabel('Sales')
ax.set_ylabel('Profit')
plt.show()

# %%
data = retail[(retail['Sub-Category'] == 'Bookcases') | (retail['Sub-Category'] == 'Tables')].sort_values('Profit')
plt.figure(figsize=(15,5))
plt.title('Overall Profit - Tables & Bookcases', fontsize=15)
sns.barplot(data['State'], data.Profit)
plt.xticks(rotation=75)
plt.show()
# Out:
# C:\Users\DERLIN DOMINIC\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ps = retail.groupby('State')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False)
ps[:].plot.bar(figsize=(15,10))
plt.title('SALES & PROFIT ACROSS STATES')
plt.xlabel('States')
plt.ylabel('Sales/Profit')
plt.show()

# %% [markdown]
# Highest Sales is at California and New York Sates while Lowest Profit is at Texas and Ohio States

# %%
retail.groupby('Region')['Sales','Profit'].sum().plot.bar()
plt.title('Sale & profit in each region')
plt.legend()
plt.show()
# Out:
# <ipython-input-13-0ce1d13d4951>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   retail.groupby('Region')['Sales','Profit'].sum().plot.bar()

# %% [markdown]
# East and west are better performing regions in sales and profit

# %% [markdown]
# ### CONCLUSION

# %% [markdown]
# - The profit is in a good range when the discount is minimal, and there is no discount. incurring small losses, the company gains in the future by attracting more long term customers. Therefore, the small losses from discounts are an essential part of company's business.
# - States except Pennsylvania, Texas & Illinois has profit in sales of Chairs & Furnishings.
# - The business should focus on West and East Regions as they have better Sales and Profit than Cenatral and south Regions. Make business strategies to attract the central and sounth regions.Technology Category has the highest profit at East Region and Furniture has the least profit at Central Region.Technology Category has the highest sales at South Region.
# - Highest Segment is Consumer Segment following with Corporate segment.
